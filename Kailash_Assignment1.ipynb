# %% [markdown]
# # Assignment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('Dataset_data_divination.csv')
df
# Out:
#       Unnamed: 0 Service_provider technology Download_Upload  \
# 0              0           AIRTEL         4G        download
# 1              1           AIRTEL         4G          upload
# 2              2              JIO         4G        download
# 3              3              JIO         4G        download
# 4              4              JIO         4G          upload
# ...          ...              ...        ...             ...
# 3995        3995              JIO         4G          upload
# 3996        3996         VODAFONE         4G        download
# 3997        3997         VODAFONE         4G        download
# 3998        3998              JIO         4G        download
# 3999        3999         VODAFONE         4G          upload
#
#       Data_Speed(Kbps)  signal_strength Service_Area
# 0                 4794            -53.0      UP East
# 1                  536            -59.0      UP East
# 2                38507            -59.0      UP West
# 3                78938            -59.0      UP West
# 4                 3560            -59.0      UP West
# ...                ...              ...          ...
# 3995              5419            -69.0      UP East
# 3996               139              NaN        Delhi
# 3997                22            -73.0        Delhi
# 3998             14804            -61.0        Delhi
# 3999              1020            -73.0        Delhi
#
# [4000 rows x 7 columns]

# %% [markdown]
# #### 1. Replace- ('AIRTEL', 'JIO', 'CELLONE', 'VODAFONE', 'IDEA') with (0,1,2,3,4) respectively

# %%
df.loc[df['Service_provider'] == 'AIRTEL', 'Service_provider'] = '0'
df.loc[df['Service_provider'] == 'JIO', 'Service_provider'] = '1'
df.loc[df['Service_provider'] == 'CELLONE', 'Service_provider'] = '2'
df.loc[df['Service_provider'] == 'VODAFONE', 'Service_provider'] = '3'
df.loc[df['Service_provider'] == 'IDEA', 'Service_provider'] = '4'

df
# Out:
#       Unnamed: 0 Service_provider technology Download_Upload  \
# 0              0                0         4G        download
# 1              1                0         4G          upload
# 2              2                1         4G        download
# 3              3                1         4G        download
# 4              4                1         4G          upload
# ...          ...              ...        ...             ...
# 3995        3995                1         4G          upload
# 3996        3996                3         4G        download
# 3997        3997                3         4G        download
# 3998        3998                1         4G        download
# 3999        3999                3         4G          upload
#
#       Data_Speed(Kbps)  signal_strength Service_Area
# 0                 4794            -53.0      UP East
# 1                  536            -59.0      UP East
# 2                38507            -59.0      UP West
# 3                78938            -59.0      UP West
# 4                 3560            -59.0      UP West
# ...                ...              ...          ...
# 3995              5419            -69.0      UP East
# 3996               139              NaN        Delhi
# 3997                22            -73.0        Delhi
# 3998             14804            -61.0        Delhi
# 3999              1020            -73.0        Delhi
#
# [4000 rows x 7 columns]

# %% [markdown]
# #### 2. Replace- (dowload,upload) with (0,1) respectively.

# %%
df.loc[df['Download_Upload'] == 'download', 'Download_Upload'] = '0'
df.loc[df['Download_Upload'] == 'upload', 'Download_Upload'] = '1'

df
# Out:
#       Unnamed: 0 Service_provider technology Download_Upload  \
# 0              0                0         4G               0
# 1              1                0         4G               1
# 2              2                1         4G               0
# 3              3                1         4G               0
# 4              4                1         4G               1
# ...          ...              ...        ...             ...
# 3995        3995                1         4G               1
# 3996        3996                3         4G               0
# 3997        3997                3         4G               0
# 3998        3998                1         4G               0
# 3999        3999                3         4G               1
#
#       Data_Speed(Kbps)  signal_strength Service_Area
# 0                 4794            -53.0      UP East
# 1                  536            -59.0      UP East
# 2                38507            -59.0      UP West
# 3                78938            -59.0      UP West
# 4                 3560            -59.0      UP West
# ...                ...              ...          ...
# 3995              5419            -69.0      UP East
# 3996               139              NaN        Delhi
# 3997                22            -73.0        Delhi
# 3998             14804            -61.0        Delhi
# 3999              1020            -73.0        Delhi
#
# [4000 rows x 7 columns]

# %% [markdown]
# #### 3. Fill null values (if any) with median of that column.

# %%
df.fillna(df.median())
# Out:
#       Unnamed: 0 Service_provider technology Download_Upload  \
# 0              0                0         4G               0
# 1              1                0         4G               1
# 2              2                1         4G               0
# 3              3                1         4G               0
# 4              4                1         4G               1
# ...          ...              ...        ...             ...
# 3995        3995                1         4G               1
# 3996        3996                3         4G               0
# 3997        3997                3         4G               0
# 3998        3998                1         4G               0
# 3999        3999                3         4G               1
#
#       Data_Speed(Kbps)  signal_strength Service_Area
# 0                 4794            -53.0      UP East
# 1                  536            -59.0      UP East
# 2                38507            -59.0      UP West
# 3                78938            -59.0      UP West
# 4                 3560            -59.0      UP West
# ...                ...              ...          ...
# 3995              5419            -69.0      UP East
# 3996               139            -81.0        Delhi
# 3997                22            -73.0        Delhi
# 3998             14804            -61.0        Delhi
# 3999              1020            -73.0        Delhi
#
# [4000 rows x 7 columns]

# %% [markdown]
# #### 4. Calculate the mean Data_Speed of the records having Service_provider 0 or 2.

# %%
a = df.loc[df['Service_provider'] == 0|2, 'Data_Speed(Kbps)']
a.mean()
# Out:
# nan

# %% [markdown]
# #### 5. Make a visualization to show the relationship between 'Service_provider' and 'Data_Speed(Kbps)' using         Matplotlib package in Python

# %%
df = pd.read_csv('Dataset_data_divination.csv')

plt.figure(figsize=(50,45))

plt.plot(df['Service_provider'], df['Data_Speed(Kbps)'], 'r')


plt.title('Dataset_data_divination', fontdict = {'fontname':'Comic Sans MS', 'fontsize': 18})

plt.xlabel('Service_provider')
plt.ylabel('Data_Speed(Kbps)')

plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #### 6. Count the number of records having signal_strength less than -78.

# %% [markdown]
# #### 7. Explain about the nature of Histogram of 'Data_Speed(Kbps)' feature. Visualize it using Seaborn library.

# %% [markdown]
# #### 8. Describe the numerical features in the data-set statistically.

# %%
df.describe()
# Out:
#         Unnamed: 0  Data_Speed(Kbps)  signal_strength
# count  4000.000000       4000.000000      3452.000000
# mean   1999.500000       8315.810000       -82.202491
# std    1154.844867      15561.302023        18.173601
# min       0.000000          0.000000      -112.000000
# 25%     999.750000        772.750000      -100.000000
# 50%    1999.500000       2749.500000       -81.000000
# 75%    2999.250000       7968.250000       -67.000000
# max    3999.000000      80755.000000       -51.000000

# %% [markdown]
# #### 9. Model the Regression relationship between Data_Speed(Kbps) and signal_strength
